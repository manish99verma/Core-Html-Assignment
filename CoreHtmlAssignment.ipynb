# %% [markdown]
# 1. Build a simple webpage that displays text as shown in the below image.
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#   </head>
#   <body style="display: flex; flex-direction: column; row-gap: 10px">
#     <b>This text will be bolded!</b>
#     <i>This text will be italic.</i>
#     <u>This text will be underlined!</u>
#     <mark>This text will be highlighted!</mark>
#     <p>
#       This is normal text <sup>this is superscripted</sup> this is normal again!
#     </p>
#     <p>This is normal text <sub>this is subscripted</sub></p>
#     <p>Normal Text <small>small text</small></p>
#     <del>This text will be deleted!</del>
#   </body>
# </html>
# ```

# %% [markdown]
# 2. Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image.
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#   </head>
#   <body style="display: flex; flex-direction: column; row-gap: 10px">
#     <h1>Navigate Me:</h1>
#     <p>
#       Take me to
#       <a href="https://pwskills.com/" target="_blank">pw skills </a> to buy a
#       course.
#     </p>
#     <p>
#       Take me to
#       <a href="https://developer.mozilla.org/en-US/" target="_blank"
#         >MDN Docs
#       </a>
#       to know more about web development!
#     </p>
#     <p>
#       Take me to
#       <a href="https://pwskills.com/" target="_blank">PW Skills Lab </a>
#       to practice live coding!
#     </p>
#     <p>Sorry! I am unable to find PW Skills Lab url!</p>
#   </body>
# </html>
# ```

# %% [markdown]
# 3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information. For the home page you can add some information about yourself.
# - Live Url: https://manish99verma.github.io/manish-blog/index.html
# <br>
# Github Ulr: https://github.com/manish99verma/manish-blog
# <br>
# Home Page:
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Home Page</title>
#   </head>
#   <body
#     style="
#       display: flex;
#       flex-direction: column;
#       align-items: center;
#       justify-content: center;
#       row-gap: 8px;
#     "
#   >
#     <div style="display: flex; width: 80%; flex-direction: column">
#       <h1>This is a brief introduction about me</h1>
#       <p>
#         My name is Manish Kumar Verma. I am from nalanda (Bihar). I have
#         completed my 12th from CBSE in 2020 with 83% with PCM. After that i had
#         started learning to code through online resources. I started my journey
#         with Android App Development. Where i developed many apps like VPN,
#         Gallery locker, PUBG Wallpapers, Free Fire Wallpapers and many more. One
#         of my app "PUBG Wallpapers" got over 500K downloads on playstore.
#         Unfortunately my play console account got deactivated due to some
#         trademark issues. Then i started learning Web Dev and made only one
#         site,
#         <a href="https://shayariyana.com" target="_blank">Shayariyana.com</a>
#         with basic knowledge in html, css and javascript .Which currently have
#         more than 500K monthly active users.
#       </p>
#       <a href="web-development.html">Web Development</a>
#       <a href="web-design.html">Web Design</a>
#     </div>
#   </body>
# </html>
# ```
#
# Web design Page:
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Web Development</title>
#   </head>
#   <body
#     style="
#       display: flex;
#       flex-direction: column;
#       align-items: center;
#       justify-items: center;
#     "
#   >
#     <div style="display: flex; flex-direction: column; width: 80%">
#       <h1>🌐 Web Design Guide for Beginners & Advanced Users</h1>
#       <p>
#         Web design involves creating visually appealing, user-friendly, and
#         responsive websites that provide a great user experience. Since you're
#         already working with Next.js, Tailwind CSS, and Astro, you can leverage
#         these technologies for modern web design.
#       </p>
#       <hr />
#       <h2>🔹 Key Web Design Principles</h2>
#       <ol>
#         <li>Simplicity – Keep the UI clean and clutter-free.</li>
#         <li>
#           Consistency – Use a consistent color scheme, typography, and spacing.
#         </li>
#         <li>Mobile-First Design – Ensure responsiveness for all devices.</li>
#         <li>
#           Fast Loading – Optimize images, use lazy loading, and leverage
#           caching.
#         </li>
#         <li>
#           Accessibility – Make the website usable for everyone, including people
#           with disabilities.
#         </li>
#       </ol>
#       <h3>🔹 Web Design Trends for 2025</h3>
#       <ul>
#         <li>Neumorphism & Glassmorphism – Soft UI effects with depth.</li>
#         <li>Dark Mode Support – Many users prefer dark-themed interfaces.</li>
#         <li>
#           AI-Powered Personalization – Dynamically adapting content for users.
#         </li>
#         <li>
#           Micro-Interactions & Animations – Subtle UI animations enhance
#           experience.
#         </li>
#         <li>Minimalism – Flat, simple, and easy-to-navigate layouts.</li>
#       </ul>
#       <h3>🔹 Tools for Web Design</h3>
#       <span>✅ Figma/XD – For designing UI/UX before coding.</span>
#       <span>✅ Tailwind CSS – For fast, utility-first styling.</span>
#       <span>✅ Framer Motion – For smooth animations in Next.js.</span>
#       <span>✅ LottieFiles – For lightweight vector animations.</span>
#       <span>✅ Three.js – For 3D effects in websites.</span>
#       <br />
#       <a href="index.html">Home</a>
#       <br />
#       <a href="web-development.html">Web Development</a>
#     </div>
#   </body>
# </html>
# ```
#
# Web Developement Page:
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Web Development</title>
#   </head>
#   <body
#     style="
#       display: flex;
#       flex-direction: column;
#       align-items: center;
#       justify-items: center;
#     "
#   >
#     <div style="display: flex; flex-direction: column; width: 80%">
#       <h1>🌐 Web Development Guide for Beginners & Advanced Users</h1>
#       <p>
#         Web development involves building websites and web applications. It
#         includes Frontend (UI/UX), Backend (Server, Database), and Full-Stack
#         (Both Frontend & Backend).
#       </p>
#       <hr />
#       <h2>1. Types of Web Development</h2>
#       <h3>🖥️ Frontend Development (Client-Side)</h3>
#       <ul>
#         <li>Languages: HTML, CSS, JavaScript</li>
#         <li>Frameworks/Libraries: React.js, Next.js, Astro, Vue.js, Angular</li>
#         <li>Styling: Tailwind CSS, Bootstrap, SCSS</li>
#         <li>Tools: Vite, Webpack, Parcel</li>
#       </ul>
#       <h3>⚙️ Backend Development (Server-Side)</h3>
#       <ul>
#         <li>
#           Languages: Node.js (Express.js, NestJS), Python (Django, Flask), PHP
#           (Laravel), Ruby on Rails
#         </li>
#         <li>Databases: MySQL, PostgreSQL, MongoDB, Firebase, Supabase</li>
#         <li>Authentication: JWT, OAuth, Firebase Auth</li>
#         <li>Server Management: Apache, Nginx, PM2, Docker</li>
#       </ul>
#       <h3>🔄 Full-Stack Development</h3>
#       <ul>
#         <li>Combines Frontend + Backend</li>
#         <li>Popular Stacks:</li>
#         <ul>
#           <li>MERN (MongoDB, Express.js, React, Node.js)</li>
#           <li>MEVN (MongoDB, Express.js, Vue.js, Node.js)</li>
#           <li>LAMP (Linux, Apache, MySQL, PHP)</li>
#         </ul>
#       </ul>
#       <h2>📌 2. How to Start Web Development</h2>
#       <h3>Step 1: Learn HTML, CSS, JavaScript</h3>
#       <ul>
#         <li>HTML → Structure of the webpage</li>
#         <li>CSS → Styling & layout (Tailwind, Bootstrap)</li>
#         <li>JavaScript → Interactive & dynamic content</li>
#       </ul>
#       <h3>Step 2: Learn Frontend Frameworks</h3>
#       <ul>
#         <li>React.js + Next.js (Best for SEO & performance)</li>
#         <li>Astro.js (Great for static websites)</li>
#         <li>Vue.js or Angular (Alternatives)</li>
#       </ul>
#       <h3>Step 3: Learn Backend & Database</h3>
#       <ul>
#         <li>Node.js (Express.js) + MongoDB (Easiest for beginners)</li>
#         <li>OR Django + PostgreSQL (Python-based alternative)</li>
#         <li>Authentication, API handling, and security</li>
#       </ul>
#       <h3>Step 4: Learn Hosting & Deployment</h3>
#       <ul>
#         <li>Static Sites: Vercel, Netlify, GitHub Pages</li>
#         <li>Full-Stack Apps: OVH VPS, Cloudflare, DigitalOcean, AWS</li>
#         <li>Databases: MongoDB Atlas, Firebase, PlanetScale</li>
#       </ul>
#
#       <br />
#       <a href="index.html">Home</a>
#       <br />
#       <a href="web-design.html">Web Design</a>
#     </div>
#   </body>
# </html>
# ```

# %% [markdown]
# 4. Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#   </head>
#   <body>
#     <ol>
#       <li>
#         <strong>&lt;html&gt;</strong> - The root element of an HTML document
#         that contains all other elements.
#       </li>
#       <li>
#         <strong>&lt;head&gt;</strong> - Contains metadata such as the title,
#         character encoding, and linked stylesheets.
#       </li>
#       <li>
#         <strong>&lt;title&gt;</strong> - Sets the title of the web page, which
#         appears in the browser tab.
#       </li>
#       <li>
#         <strong>&lt;body&gt;</strong> - Holds all the visible content of the web
#         page.
#       </li>
#       <li>
#         <strong>&lt;h1&gt; to &lt;h6&gt;</strong> - Define headings, where
#         &lt;h1&gt; is the largest and &lt;h6&gt; is the smallest.
#       </li>
#       <li><strong>&lt;p&gt;</strong> - Represents a paragraph of text.</li>
#       <li>
#         <strong>&lt;a&gt;</strong> - Defines a hyperlink, allowing users to
#         navigate to another page or section.
#       </li>
#       <li>
#         <strong>&lt;img&gt;</strong> - Embeds an image using the "src" attribute
#         to specify the image URL.
#       </li>
#       <li>
#         <strong>&lt;ul&gt;</strong> - Creates an unordered list, typically
#         displayed with bullet points.
#       </li>
#       <li>
#         <strong>&lt;ol&gt;</strong> - Creates an ordered list, typically
#         displayed with numbers.
#       </li>
#       <li>
#         <strong>&lt;li&gt;</strong> - Represents a list item inside &lt;ul&gt;
#         or &lt;ol&gt;.
#       </li>
#       <li>
#         <strong>&lt;div&gt;</strong> - A generic container used to group and
#         style elements.
#       </li>
#       <li>
#         <strong>&lt;span&gt;</strong> - A small inline container used for
#         styling a part of text.
#       </li>
#       <li><strong>&lt;table&gt;</strong> - Creates a table structure.</li>
#       <li><strong>&lt;tr&gt;</strong> - Represents a row in a table.</li>
#       <li>
#         <strong>&lt;td&gt;</strong> - Represents a data cell in a table row.
#       </li>
#       <li>
#         <strong>&lt;th&gt;</strong> - Represents a header cell in a table row.
#       </li>
#       <li>
#         <strong>&lt;form&gt;</strong> - Defines an interactive form for user
#         input.
#       </li>
#       <li>
#         <strong>&lt;input&gt;</strong> - Defines an input field in a form (e.g.,
#         text, checkbox, radio).
#       </li>
#       <li><strong>&lt;button&gt;</strong> - Represents a clickable button.</li>
#     </ol>
#   </body>
# </html>
# ```

# %% [markdown]
# 5. Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Full Stack Web Development Tech Stack</title>
#   </head>
#   <body>
#     <h2>Full Stack Web Development Tech Stack</h2>
#
#     <dl>
#       <dt><strong>HTML (HyperText Markup Language)</strong></dt>
#       <dd>The standard language used to create the structure of web pages.</dd>
#
#       <dt><strong>CSS (Cascading Style Sheets)</strong></dt>
#       <dd>
#         Used to style and design web pages, making them visually appealing.
#       </dd>
#
#       <dt><strong>JavaScript</strong></dt>
#       <dd>
#         A scripting language that adds interactivity and dynamic behavior to
#         websites.
#       </dd>
#
#       <dt><strong>React.js</strong></dt>
#       <dd>
#         A popular JavaScript library for building interactive user interfaces.
#       </dd>
#
#       <dt><strong>Vue.js</strong></dt>
#       <dd>
#         A progressive JavaScript framework for building user interfaces with
#         ease.
#       </dd>
#
#       <dt><strong>Node.js</strong></dt>
#       <dd>
#         A JavaScript runtime that allows running JavaScript on the server side.
#       </dd>
#
#       <dt><strong>Express.js</strong></dt>
#       <dd>
#         A lightweight and fast backend web framework for Node.js applications.
#       </dd>
#
#       <dt><strong>MongoDB</strong></dt>
#       <dd>
#         A NoSQL database that stores data in flexible JSON-like documents.
#       </dd>
#
#       <dt><strong>MySQL</strong></dt>
#       <dd>A widely-used relational database management system (RDBMS).</dd>
#
#       <dt><strong>PostgreSQL</strong></dt>
#       <dd>
#         An advanced, open-source relational database known for performance and
#         reliability.
#       </dd>
#
#       <dt><strong>Python</strong></dt>
#       <dd>
#         A powerful and easy-to-learn programming language often used for backend
#         development.
#       </dd>
#
#       <dt><strong>Django</strong></dt>
#       <dd>
#         A high-level Python framework that encourages rapid development and
#         clean code.
#       </dd>
#
#       <dt><strong>Flask</strong></dt>
#       <dd>
#         A lightweight Python web framework useful for building simple
#         applications.
#       </dd>
#
#       <dt><strong>PHP</strong></dt>
#       <dd>A server-side scripting language used for dynamic web content.</dd>
#
#       <dt><strong>Laravel</strong></dt>
#       <dd>
#         A PHP framework that simplifies web application development with
#         built-in tools.
#       </dd>
#
#       <dt><strong>GraphQL</strong></dt>
#       <dd>
#         A query language for APIs that allows fetching exactly the required
#         data.
#       </dd>
#
#       <dt><strong>REST API</strong></dt>
#       <dd>An architectural style for building scalable web services.</dd>
#
#       <dt><strong>Git & GitHub</strong></dt>
#       <dd>
#         Version control system and cloud-based repository for managing code
#         efficiently.
#       </dd>
#
#       <dt><strong>Docker</strong></dt>
#       <dd>
#         A platform for containerizing applications, making deployment easier.
#       </dd>
#
#       <dt><strong>Kubernetes</strong></dt>
#       <dd>
#         An orchestration tool for managing and scaling containerized
#         applications.
#       </dd>
#
#       <dt>
#         <strong>CI/CD (Continuous Integration & Continuous Deployment)</strong>
#       </dt>
#       <dd>A development practice that automates testing and deployment.</dd>
#     </dl>
#   </body>
# </html>
#
# ```

# %% [markdown]
# 6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech stack, create a table that lists the tech stack name, its primary use cases, and some key features or benefits. Below is a reference image.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Full Stack Web Development Tech Stack</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#         .container {
#             border: 2px solid black;
#             padding: 15px;
#             margin: 20px 0;
#         }
#         h2 {
#             margin-bottom: 5px;
#         }
#         table {
#             width: 100%;
#             border-collapse: collapse;
#             margin-top: 10px;
#         }
#         th, td {
#             border: 1px solid black;
#             padding: 8px;
#             text-align: left;
#         }
#         th {
#             background-color: #f2f2f2;
#             font-weight: bold;
#         }
#         ul {
#             margin: 0;
#             padding-left: 15px;
#         }
#     </style>
# </head>
# <body>
#
#     <h1>Full Stack Web Development Tech Stack</h1>
#
#     <div class="container">
#         <h2>1. HTML</h2>
#         <table>
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/Benefits</th>
#             </tr>
#             <tr>
#                 <td>Building the structure of web pages</td>
#                 <td>
#                     <ul>
#                         <li>Simple and easy to learn</li>
#                         <li>Compatible with all web browsers</li>
#                         <li>Allows for semantic markup</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
#
#     <div class="container">
#         <h2>2. CSS</h2>
#         <table>
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/Benefits</th>
#             </tr>
#             <tr>
#                 <td>Styling and layout of web pages</td>
#                 <td>
#                     <ul>
#                         <li>Allows for separation of content and presentation</li>
#                         <li>Enables responsive design</li>
#                         <li>Offers a wide range of styling options</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
#
#     <div class="container">
#         <h2>3. JavaScript</h2>
#         <table>
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/Benefits</th>
#             </tr>
#             <tr>
#                 <td>Adding interactivity and functionality to web pages</td>
#                 <td>
#                     <ul>
#                         <li>Enables dynamic content updates</li>
#                         <li>Works with HTML and CSS to enhance user experience</li>
#                         <li>Supports both frontend and backend development (via Node.js)</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
#
# </body>
# </html>
#
# ```

# %% [markdown]
# 7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists (```<ul>```) and list items (```<li>```) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#
#     <style>
#       .list {
#         vertical-align: top;
#         margin: 0;
#         padding-left: 20px;
#       }
#       .list-item {
#         color: royalblue;
#         text-decoration: underline;
#         display: list-item;
#         width: 100%;
#       }
#       .list.level-1 {
#         list-style-type: disc;
#       }
#       .list.level-2 {
#         list-style-type: circle;
#       }
#       .list.level-3 {
#         list-style-type: square;
#       }
#     </style>
#   </head>
#   <body>
#     <h1>Table of Contents</h1>
#     <ul class="list level-1">
#       <li class="list-item">Part 1: Introduction</li>
#       <li class="list-item">
#         <span>Part 2: Getting Started</span>
#         <ul class="list level-2">
#           <li class="list-item">2.1 Installing the Software</li>
#           <li class="list-item">
#             <span>2.2 Creating a New Project</span>
#             <ul class="list level-3">
#               <li class="list-item">2.2.1 Project Templates</li>
#               <li class="list-item">2.2.2 Customizing Settings</li>
#             </ul>
#           </li>
#           <li class="list-item">
#             <span>2.3 Exploring the Interface</span>
#             <ul class="list level-3">
#               <li class="list-item">2.3.1 Toolbar Features</li>
#               <li class="list-item">
#                 <span>2.3.2 Panel Layout</span>
#                 <ul class="list level-3">
#                   <li class="list-item">2.3.2.1 Docking Panels</li>
#                   <li class="list-item">2.3.2.2 Tabbed Interface</li>
#                 </ul>
#               </li>
#             </ul>
#           </li>
#         </ul>
#       </li>
#       <li class="list-item">
#         <span>Part 3: Advanced Topics</span>
#         <ul class="list level-2">
#           <li class="list-item">
#             <span>3.1 Working with Plugins</span>
#             <ul class="list level-3">
#               <li class="list-item">3.1.1 Installing Plugins</li>
#               <li class="list-item">3.1.2 Plugin Configurations</li>
#             </ul>
#           </li>
#           <li class="list-item">
#             <span>3.2 Customizing the UI</span>
#             <ul class="list level-3">
#               <li class="list-item">3.2.1 Changing Themes</li>
#               <li class="list-item">3.2.2 Configuring Shortcuts</li>
#             </ul>
#           </li>
#           <li class="list-item">
#             <span>3.3 Optimizing Performance</span>
#             <ul class="list level-3">
#               <li class="list-item">3.3.1 Caching Strategies</li>
#               <li class="list-item">3.3.2 Resource Minification</li>
#             </ul>
#           </li>
#         </ul>
#       </li>
#       <li class="list-item">Part 4: Conclusion</li>
#     </ul>
#   </body>
# </html>
#
# ```

# %% [markdown]
# 8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column corresponds to a room. Some time slots might have multiple sessions running simultaneously in different rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule. (use table attribute “cellpadding”  to give extra padding in each table cell ).
#
# ```
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Document</title>
#
#     <style>
#       table {
#         width: 100%;
#       }
#       th,
#       td {
#         border: 1px solid black;
#       }
#     </style>
#   </head>
#   <body>
#     <h1>Conference Schedule</h1>
#     <table style="width: 100%" cellpadding="16px">
#       <tr>
#         <th>Time</th>
#         <th>Room 1</th>
#         <th>Room 2</th>
#         <th>Room 3</th>
#         <th>Room 4</th>
#       </tr>
#       <tr>
#         <td rowspan="3">9:00 AM - 10:00 Am</td>
#         <td rowspan="2">Keynote</td>
#         <td>Session A</td>
#         <td>Session B</td>
#         <td rowspan="3">Session C</td>
#       </tr>
#       <tr>
#         <td>Session D</td>
#         <td>Session E</td>
#       </tr>
#       <tr>
#         <td>10:30 AM - 11:30 AM</td>
#         <td colspan="2">Session F</td>
#       </tr>
#       <tr>
#         <td>12:00 PM - 1:00 PM</td>
#         <td colspan="4">Lunch Break</td>
#       </tr>
#       <tr>
#         <td rowspan="2">1:00 PM - 2:00 PM</td>
#         <td>Session G</td>
#         <td rowspan="2">Session H</td>
#         <td>Session I</td>
#         <td>Session J</td>
#       </tr>
#       <tr>
#         <td>Session K</td>
#         <td>Session L</td>
#         <td>Session M</td>
#       </tr>
#     </table>
#   </body>
# </html>
#
# ```
